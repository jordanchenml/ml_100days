# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    """
    請完成這個 Function 後往下執行
    """
    mse = np.average(np.sum(np.square(y - y_hat)))
    return mse

def mean_absolute_error(y, y_hat):
    """
    請完成這個 Function 後往下執行
    """
    mae = np.average(np.sum(np.abs(y - y_hat)))
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 27941.312
# The Mean absolute error is 1357.914

# %% [markdown]
# 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
# ImageNet dataset is one of the biggest visual recongnition datasets.
# The dataset is hand labeled with presence or absence of 1000 object categories,
# which is a useful resource for researchers, educators and students.
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# The dataset is collected form Flickr and other search engines.
#
# 3. 蒐集而來的資料型態為何
# All type of images are JPEG. Annotations are stored in xml.
#
# 4. 這組資料想解決的問題如何評估
# The competition is trying to enhance the state of the art in object detection and classification.
# Starting from the models which awarded first place previous years may be helpful.

# %% [markdown]
# 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 減低空車時間，意即減少接到訂單後，減少前往路徑。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# Google maps
#
# 3. 蒐集而來的資料型態為何
# csv
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 提供駕駛最短路徑，減少單筆完成時間，藉此提升訂單數量。
